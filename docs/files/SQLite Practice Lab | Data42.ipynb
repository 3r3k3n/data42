# %% [markdown]
# ## 📘 SQLite Practice Lab — Data42
# 🧠 Цель занятия
#
# Познакомиться с базой данных SQLite и языком запросов SQL, выполнив все команды прямо в браузере (JupyterLite + Pyodide).
#
# Ты научишься:
# - создавать таблицы;
# - вставлять данные;
# - выполнять выборки;
# - формировать свои запросы.

# %% [markdown]
# ⚙️ Установка и подключение SQL

# %%
import micropip
await micropip.install(["ipython-sql", "prettytable"])

# %%
# %load_ext sql
# %sql sqlite://

# %% [markdown]
# 🧩 Исправляем стиль вывода таблиц (чтобы не было KeyError: 'DEFAULT')

# %%
import prettytable as pt
if not hasattr(pt, "DEFAULT"):
    pt.DEFAULT = pt.MSWORD_FRIENDLY

# %% [markdown]
# 🏗️ Создание таблицы students

# %%
# %%sql
# CREATE TABLE IF NOT EXISTS students (
#     id INTEGER PRIMARY KEY AUTOINCREMENT,
#     name TEXT,
#     age INTEGER,
#     major TEXT
# );

# %% [markdown]
# 🧍‍♀️ Добавление данных в таблицу

# %%
# %%sql
# INSERT INTO students (name, age, major) VALUES
#  ('Alice', 22, 'Data Science'),
#  ('Bob', 23, 'Computer Engineering'),
#  ('Charlie', 21, 'Mathematics');

# %% [markdown]
# 🔍 Просмотр таблицы

# %%
# %%sql
# SELECT * FROM students;

# %% [markdown]
# 💡 Задание для самостоятельной работы
#
# 1) Добавь себя как студента с направлением "Data Engineering".
# 2) Выведи всех студентов, которым больше 21 года.
# 3) Попробуй добавить новый столбец "city" и вставить данные.
# 4) Найди средний возраст студентов в таблице.
